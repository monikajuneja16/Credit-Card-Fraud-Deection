# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.metrics import accuracy_score, f1_score,precision_score,recall_score,matthews_corrcoef
from matplotlib import gridspec
sns.set()

# %%
data=pd.read_csv('creditcard.csv')

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
data.hist(figsize=(20,20))
plt.show()

# %%
fraud = data[data['Class'] == 1] 
valid = data[data['Class'] == 0]
print(fraud.shape,valid.shape)
# Out:
# (492, 31) (284315, 31)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
fraction = len(fraud)/float(len(valid))
print(fraction)
# Out:
# 0.0017304750013189597

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
valid.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
corr_matrix=data.corr()
fig=plt.figure(figsize=(12,9))
sns.heatmap(corr_matrix,vmax=0.8,square=True)

# %%
X=data.drop(['Class'], axis=1)
Y=data['Class']
print(X.shape)
print(Y.shape)
X_data=X.values
Y_data=Y.values
# Out:
# (284807, 30)
# (284807,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size = 0.2, random_state = 42)

# %%
from sklearn.ensemble import IsolationForest
ifc=IsolationForest(max_samples=len(X_train),
 contamination=fraction,random_state=1)
ifc.fit(X_train)
scores_pred = ifc.decision_function(X_train)
y_pred = ifc.predict(X_test)
# Out:
# C:\Users\Monika\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\Users\Monika\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)

# %%
from sklearn.metrics import confusion_matrix
y_pred[y_pred == 1] = 0
y_pred[y_pred == -1] = 1

n_errors = (y_pred != Y_test).sum()
LABELS = ['Normal', 'Fraud']
conf_matrix = confusion_matrix(Y_test, y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(conf_matrix, xticklabels=LABELS,
 yticklabels=LABELS, annot=True, fmt='d');
plt.title('Confusion matrix')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
from sklearn.metrics import accuracy_score, f1_score,precision_score,recall_score,matthews_corrcoef

n_outliers = len(fraud)
print('the Model used is {}'.format('Isolation Forest'))
acc= accuracy_score(Y_test,y_pred)
print('The accuracy is {}'.format(acc))
prec= precision_score(Y_test,y_pred)
print('The precision is {}'.format(prec))
rec= recall_score(Y_test,y_pred)
print('The recall is {}'.format(rec))
f1= f1_score(Y_test,y_pred)
print('The F1-Score is {}'.format(f1))
MCC=matthews_corrcoef(Y_test,y_pred)
print('The Matthews correlation coefficient is{}'.format(MCC))
print('Errors are {}'.format(n_errors))
# Out:
# the Model used is Isolation Forest
# The accuracy is 0.9978933323970366
# The precision is 0.375
# The recall is 0.336734693877551
# The F1-Score is 0.3548387096774193
# The Matthews correlation coefficient is0.3543008067850027
# Errors are 120

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(X_train,Y_train)
y_predr=rfc.predict(X_test)
# Out:
# C:\Users\Monika\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
n_errors = (y_predr != Y_test).sum()
LABELS = ['Normal', 'Fraud']
conf_matrix = confusion_matrix(Y_test, y_predr)
plt.figure(figsize=(10, 10))
sns.heatmap(conf_matrix, xticklabels=LABELS,
 yticklabels=LABELS, annot=True,fmt='d',annot_kws={"size": 16});
plt.title('Confusion matrix')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
from sklearn.metrics import accuracy_score, f1_score,precision_score,recall_score,matthews_corrcoef
n_errors=(y_predr !=Y_test).sum()
n_outliers = len(fraud)
print('the Model used is {}'.format('Random Forest'))
acc= accuracy_score(Y_test,y_predr)
print('The accuracy is {}'.format(acc))
prec= precision_score(Y_test,y_predr)
print('The precision is {}'.format(prec))
rec= recall_score(Y_test,y_predr)
print('The recall is {}'.format(rec))
f1= f1_score(Y_test,y_predr)
print('The F1-Score is {}'.format(f1))
MCC=matthews_corrcoef(Y_test,y_predr)
print('The Matthews correlation coefficient is {}'.format(MCC))
print('Errors are {}'.format(n_errors))
# Out:
# the Model used is Random Forest
# The accuracy is 0.9994908886626171
# The precision is 0.948051948051948
# The recall is 0.7448979591836735
# The F1-Score is 0.8342857142857143
# The Matthews correlation coefficient is 0.8401237605405719
# Errors are 29

# %%
from sklearn.tree import DecisionTreeClassifier 

dtcf=DecisionTreeClassifier()
dtcf.fit(X_train,Y_train)
y_predd=dtcf.predict(X_test)

n_errors=(y_predd!=Y_test).sum()
print('the Model used is {}'.format('Decission Tree'))
acc= accuracy_score(Y_test,y_predd)
print('The accuracy is {}'.format(acc))
prec= precision_score(Y_test,y_predd)
print('The precision is {}'.format(prec))
rec= recall_score(Y_test,y_predd)
print('The recall is {}'.format(rec))
f1= f1_score(Y_test,y_predd)
print('The F1-Score is {}'.format(f1))
MCC=matthews_corrcoef(Y_test,y_predd)
print('The Matthews correlation coefficient is {}'.format(MCC))
print('Errors are {}'.format(n_errors))


LABELS = ['Normal', 'Fraud']
conf_matrix = confusion_matrix(Y_test, y_predd)
plt.figure(figsize=(10, 10))
sns.heatmap(conf_matrix, xticklabels=LABELS,
 yticklabels=LABELS, annot=True, fmt='d');
plt.title('Confusion matrix')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# the Model used is Decission Tree
# The accuracy is 0.9990344440153085
# The precision is 0.6936936936936937
# The recall is 0.7857142857142857
# The F1-Score is 0.736842105263158
# The Matthews correlation coefficient is 0.7377941865532832
# Errors are 55

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, Y_train)
y_predg = nb.predict(X_test)

# %%
n_errors = (y_predg != Y_test).sum()
LABELS = ['Normal', 'Fraud']
conf_matrix = confusion_matrix(Y_test, y_predg)
plt.figure(figsize=(10, 10))
sns.heatmap(conf_matrix, xticklabels=LABELS,
 yticklabels=LABELS, annot=True, fmt='d');
plt.title('Confusion matrix')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
print('the Model used is {}'.format('Naive Bayes'))
acc= accuracy_score(Y_test,y_predg)
print('The accuracy is {}'.format(acc))
prec= precision_score(Y_test,y_predg)
print('The precision is {} '.format(prec))
rec= recall_score(Y_test,y_predg)
print('The recall is {}'.format(rec))
f1= f1_score(Y_test,y_predg)
print('The F1-Score is {}'.format(f1))
MCC=matthews_corrcoef(Y_test,y_predg)
print('The Matthews correlation coefficient is {}'.format(MCC))
print('Errors are {}'.format(n_errors))
# Out:
# the Model used is Naive Bayes
# The accuracy is 0.9930128857835048
# The precision is 0.14622641509433962
# The recall is 0.6326530612244898
# The F1-Score is 0.2375478927203065
# The Matthews correlation coefficient is 0.3019617859258202
# Errors are 398

# %%
from sklearn.linear_model import LogisticRegression
nb = LogisticRegression()
nb.fit(X_train, Y_train)
y_preds = nb.predict(X_test)
n_errors = (y_preds != Y_test).sum()
LABELS = ['Normal', 'Fraud']
conf_matrix = confusion_matrix(Y_test, y_preds)
plt.figure(figsize=(10, 10))
sns.heatmap(conf_matrix, xticklabels=LABELS,
 yticklabels=LABELS, annot=True, fmt='d');
plt.title('Confusion matrix')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# C:\Users\Monika\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
print('the Model used is {}'.format('Logistic Regression Classifier'))
acc= accuracy_score(Y_test,y_preds)
print('The accuracy is {}'.format(acc))
prec= precision_score(Y_test,y_preds,labels=np.unique(y_preds))
print('The precision is {}'.format(prec))
rec= recall_score(Y_test,y_preds)
print('The recall is {}'.format(rec))
f1= f1_score(Y_test,y_preds)
print('The F1-Score is {}'.format(f1))
MCC=matthews_corrcoef(Y_test,y_preds)
print('The Matthews correlation coefficient is {}'.format(MCC))
print('Errors are {}'.format(n_errors))
# Out:
# the Model used is Logistic Regression Classifier
# The accuracy is 0.9989993328885924
# The precision is 0.8253968253968254
# The recall is 0.5306122448979592
# The F1-Score is 0.6459627329192548
# The Matthews correlation coefficient is 0.6613449759956226
# Errors are 57
